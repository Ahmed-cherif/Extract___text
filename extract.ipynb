# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahmed-cherif/Extract___text/blob/main/extract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

def extract_month_and_year(text):
    # Define regular expression patterns for month and year extraction
    month_pattern = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)'
    year_pattern = r'\d{4}'

    # Search for month and year patterns in the text
    month_match = re.search(month_pattern, text, re.IGNORECASE)
    year_match = re.search(year_pattern, text)

    # Extract and format the matched month and year
    if month_match:
        extracted_month = month_match.group(0)
    else:
        extracted_month = None

    if year_match:
        extracted_year = year_match.group(0)
    else:
        extracted_year = None

    return extracted_month, extracted_year

# Test the function with an example text
example_text = "The event will take place in October 2023."
month, year = extract_month_and_year(example_text)
if month and year:
    print(f"Extracted Month: {month}, Year: {year}")
elif month:
    print(f"Extracted Month: {month}")
elif year:
    print(f"Extracted Year: {year}")
else:
    print("No month or year found in the text.")
# Example 1
text1 = "The deadline for submission is September 2023."
month1, year1 = extract_month_and_year(text1)
print(f"Extracted Month: {month1}, Year: {year1}")

# Example 2
text2 = "Join us for the conference in May."
month2, year2 = extract_month_and_year(text2)
print(f"Extracted Month: {month2}, Year: {year2}")

# Example 3
text3 = "The project is scheduled for completion in December of 2022."
month3, year3 = extract_month_and_year(text3)
print(f"Extracted Month: {month3}, Year: {year3}")

# Example 4
text4 = "No specific date was mentioned."
month4, year4 = extract_month_and_year(text4)
if month4 or year4:
    print(f"Extracted Month: {month4}, Year: {year4}")
else:
    print("No month or year found in the text.")
# Out:
# Extracted Month: October, Year: 2023
# Extracted Month: September, Year: 2023
# Extracted Month: May, Year: None
# Extracted Month: December, Year: 2022
# No month or year found in the text.

# %%
import re

def extract_school_info(text):
    # Modèle d'expression régulière pour extraire les titres (ingénieur/non ingénieur), années et noms d'écoles/universités
    pattern = r'(\d{4})?\s*:\s*((?:Diplôme|Licence|Master|MSc)\s+[A-Za-z\s\-]+)\s*(?:-\s*(?:[A-Za-z\s\-]+))?\s*(?:-\s*Mention\s[A-Za-z\s\-]+)?'

    # Liste des noms d'écoles et d'universités en Tunisie
    school_names = [
    r'(?:enis|enit|ensi|esprit|ult|isimm|eniso|tek|up|enig|ensit|fseg|iset|isg|insat|ihec|iscae|issat|esstt|ipeit|esiam|ensiem|ipest|esa|esa2|esae|esib|esm|esprit|esst|isam|isbm|iscom|iset|isetcom)',
    # Ajoutez les noms supplémentaires ici
]


    # Combinez les noms d'écoles en un seul motif
    school_pattern = r'\b(?:' + '|'.join(school_names) + r')\b'

    # Trouver toutes les occurrences du motif dans le texte
    matches = re.findall(pattern, text, re.IGNORECASE)
    school_matches = re.findall(school_pattern, text, re.IGNORECASE)

    # Extraire et formater les années, titres (ingénieur/non ingénieur) et noms d'écoles/universités
    extracted_years = [match[0] for match in matches if match[0]]
    extracted_titles = [match[1] for match in matches if match[1]]

    # Identifier si le titre contient "ingénieur" ou "non ingénieur"
    extracted_title_types = []
    for title in extracted_titles:
        if "ingénieur" in title.lower():
            extracted_title_types.append("Ingénieur")
        else:
            extracted_title_types.append("Non Ingénieur")

    extracted_info = {
        "Année": extracted_years,
        "Titre (Ingénieur/Non Ingénieur)": extracted_title_types,
        "Noms d'écoles/universités cités": school_matches
    }

    return extracted_info if any(extracted_info.values()) else None

# Liste des exemples de lignes
exemples = [
    "Diplôme national d’ingénieur en informatique",
    "Esprit - School of Engineering - Mention Très Bien",
    "2016 : Diplôme national d'ingénieur en génie informatique- ULT – Tunisie",
    "2013 : Licence Fondamentale des sciences en informatique –ISIMM- Tunisie",
]

# Appliquer l'algorithme à chaque exemple de ligne
for i, exemple in enumerate(exemples, start=1):
    extracted_info = extract_school_info(exemple)
    if extracted_info:
        print(f"Exemple - Ligne {i}:")
        for key, value in extracted_info.items():
            print(f"{key}: {value}")
    else:
        print(f"Aucune information trouvée - Ligne {i}.")
# Out:
# Aucune information trouvée - Ligne 1.
# Exemple - Ligne 2:
# Année: []
# Titre (Ingénieur/Non Ingénieur): []
# Noms d'écoles/universités cités: ['Esprit']
# Exemple - Ligne 3:
# Année: ['2016']
# Titre (Ingénieur/Non Ingénieur): ['Non Ingénieur']
# Noms d'écoles/universités cités: ['ULT']
# Exemple - Ligne 4:
# Année: ['2013']
# Titre (Ingénieur/Non Ingénieur): ['Non Ingénieur']
# Noms d'écoles/universités cités: ['ISIMM']
